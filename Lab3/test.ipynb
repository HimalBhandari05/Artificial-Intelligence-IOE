# %%
import joblib

model = joblib.load(filename="models/model.joblib")
model.predict(
    [
        "This movie is very nice and it covers everything related to devices like smart phones , computers , laptop etc."
    ]
)
# Out:
# array(['tech'], dtype='<U13')
